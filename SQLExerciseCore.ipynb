# %% [markdown]
# <a href="https://colab.research.google.com/github/jessamcs/Week-12-SQL/blob/main/SQLExerciseCore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine

# %%
# load data - change the path to match your drive!
school = pd.read_csv('/content/School_Details (1).csv')
# load table 2
facility = pd.read_csv('/content/School_Facility_Details.csv')

# %%
# create sqlite engine
engine = create_engine('sqlite:///school.db', echo=True)
# create connection to engine
conn = engine.connect()

# %%
# add the dataframe as a table in sqlite
sqlite_table = "school_details"
school.to_sql(sqlite_table, conn, if_exists='fail')
sqlite_table2 = "school_facility_details"
facility.to_sql(sqlite_table2, conn, if_exists='fail')
# Out:
# 2022-02-09 15:50:42,958 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# 2022-02-09 15:50:42,960 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 15:50:42,963 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_details")
# 2022-02-09 15:50:42,965 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 15:50:42,980 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance (in Km)" FLOAT,
# 	"CRCDistance (in Km)" FLOAT,
# 	"BACDistance (in Km)" FLOAT,
# 	"IsRecognized" TEXT,
# 	"RecognizedBy" TEXT,
# 	"ContactPersonName" FLOAT,
# 	"LowestClass" TEXT,
# 	"HighestClass" TEXT,
# 	"BoardName" TEXT
# )
#
#
# 2022-02-09 15:50:42,982 INFO sqlalchemy.engine.Engine [no key 0.00219s] ()
# 2022-02-09 15:50:43,000 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 15:50:43,002 INFO sqlalchemy.engine.Engine CREATE INDEX ix_school_details_index ON school_details ("index")
# 2022-02-09 15:50:43,004 INFO sqlalchemy.engine.Engine [no key 0.00140s] ()
# 2022-02-09 15:50:43,019 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 15:50:43,033 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-02-09 15:50:43,120 INFO sqlalchemy.engine.Engine INSERT INTO school_details ("index", "DistrictName", "EstablishmentCode", "EstablishmentName", "BRCName", "CRCName", "SchoolLevel", "ManagementName", "LocalityHabitation", "SubdivisionName", "ConstituencyName", "RevenueBlockName", "CivicBodyName", "WardName", "PostOfficeName", "PhoneNo", "FaxNo", "EmailID", "Website", "LocatedInRuralOrUrban", "DiseCode", "EstablishedDate", "DistrictHQDistance (in Km)", "CRCDistance (in Km)", "BACDistance (in Km)", "IsRecognized", "RecognizedBy", "ContactPersonName", "LowestClass", "HighestClass", "BoardName") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-02-09 15:50:43,122 INFO sqlalchemy.engine.Engine [generated in 0.07606s] ((0, 'East', 'S0169', 'BUDANG GOVERNMENT PRIMARY SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'BUDANG', 'Gangtok', 'Rhenock', 'Central Pendam', 'Central Pendam', 'Sajong', 'Upper Pendam', None, None, None, None, 'Urban Area', None, '28126', 58.0, 8.0, 16.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 5', None), (1, 'East', 'S0099', 'CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SSS', 'State Govt.', 'CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Karmithang', 'Upper Pendam', '3592263812', None, None, None, 'Urban Area', '800401', '15342', 50.0, 0.0, 6.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 12', 'C.B.S.E.'), (2, 'East', 'S0848', 'CENTRAL POINT ACADEMY, CENTRAL PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'Private (Unaided)', 'UPPER BHURUNG CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Burung', 'Upper Pendam', '03592263809/263960', None, 'ksu_5162@yahoo.com', 'www.facebook.com/khanalkeshav (Group-CPA)', 'Urban Area', None, '37257.38680555556', 49.0, 1.5, 6.0, 'Recognized', 'HRDD, GOVT. OF SIKKIM', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (3, 'East', 'S0190', 'CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'JHS', 'State Govt.', 'CHEURIBOTEY', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Cheuribotey', 'Duga', None, None, None, None, 'Urban Area', None, '28856', 60.0, 6.0, 6.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 8', None), (4, 'East', 'S0111', 'DUGA GOVERNMENT SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'State Govt.', 'DUGA', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Duga', 'Duga', '9832082915', None, 'dugaschool@gmail.com', None, 'Urban Area', None, '1828', 52.0, 0.0, 0.5, 'Recognized', 'c.b.s.e.', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (5, 'East', 'S0856', 'EASWARAMMA SAI GURUKOOL ACCADEMY', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'RALUNG', 'Gangtok', 'West Pandam', 'Central Pendam', 'West Pendam', 'Ralang', 'West Pendam', '9733056624', None, None, None, 'Urban Area', None, '40179.66805555556', 0.0, 0.2, 0.2, 'Recognized', None, None, 'Class 1', 'Class 5', None), (6, 'East', 'S0870', 'ETERNAL ENGLISH SCHOOL, WEST PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'SAKHU WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Sakhu', 'Sakhu Busty', '9734190544', None, None, None, 'Urban Area', None, '37300.66805555556', 42.0, 3.0, 4.0, 'Recognized', 'HRDD OF SIKKIM', None, 'Class 1', 'Class 5', None), (7, 'East', 'S0157', 'KHANI GOAN GOVERNMENT PRIMARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Khanigaon', 'West Pendam', '9832470263', None, None, None, 'Urban Area', '801801', '29587', 45.0, 5.0, 4.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 5', 'C.B.S.E.')  ... displaying 10 of 1249 total bound parameter sets ...  (1247, 'West', 'S0340', 'TINGTING GAON GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TING TING GAON', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Tingting', 'Yuksom', '9593377402', None, None, None, 'Urban Area', '100282', '29587', 36.0, 3.0, 6.0, 'Recognized', 'STATE GOVERNMENT', None, 'Class 1', 'Class 5', None), (1248, 'West', 'S0542', 'TSONG GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TSONG', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Yoksam', 'Yuksom', No ...
# 2022-02-09 15:50:43,144 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 15:50:43,166 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_facility_details")
# 2022-02-09 15:50:43,168 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 15:50:43,171 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_facility_details")
# 2022-02-09 15:50:43,173 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 15:50:43,180 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_facility_details (
# 	"index" BIGINT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"IsLibraryAvailable" TEXT,
# 	"AvailableBooksCount" BIGINT,
# 	"IsFireExtgAvailable" TEXT,
# 	"ExtinguisherCount" BIGINT,
# 	"HOIRoomAvailable" TEXT,
# 	"IsStaffRoomAvailable" TEXT,
# 	"NoofStaffRoom" BIGINT,
# 	"IsLockerForStaffAvailable" TEXT,
# 	"IsSportsStoreRoomAvailable" TEXT
# )
#
#
# 2022-02-09 15:50:43,183 INFO sqlalchemy.engine.Engine [no key 0.00245s] ()
# 2022-02-09 15:50:43,198 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 15:50:43,204 INFO sqlalchemy.engine.Engine CREATE INDEX ix_school_facility_details_index ON school_facility_details ("index")
# 2022-02-09 15:50:43,206 INFO sqlalchemy.engine.Engine [no key 0.00247s] ()
# 2022-02-09 15:50:43,220 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 15:50:43,225 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-02-09 15:50:43,275 INFO sqlalchemy.engine.Engine INSERT INTO school_facility_details ("index", "EstablishmentCode", "EstablishmentName", "IsLibraryAvailable", "AvailableBooksCount", "IsFireExtgAvailable", "ExtinguisherCount", "HOIRoomAvailable", "IsStaffRoomAvailable", "NoofStaffRoom", "IsLockerForStaffAvailable", "IsSportsStoreRoomAvailable") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-02-09 15:50:43,276 INFO sqlalchemy.engine.Engine [generated in 0.03899s] ((0, 'S1034', '(I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PRIMARY SCHOOL, RIMBI', 'Not Available', 0, 'Available', 1, 'Available', 'Not Available', 0, 'Not Available', 'Not Available'), (1, 'S0516', '10TH MILE GOVERNMENT PRIMARY SCHOOL', 'Not Available', 0, 'Not Available', 0, 'Available', 'Available', 1, 'Not Available', 'Not Available'), (2, 'S0237', '4TH MILE GOVERNMENT JUNIOR HIGH SCHOOL', 'Not Available', 0, 'Available', 2, 'Not Available', 'Not Available', 0, 'Not Available', 'Not Available'), (3, 'S0692', 'AAPGAZI GOVERNMENT PRIMARY SCHOOL', 'Not Available', 0, 'Not Available', 0, 'Not Available', 'Not Available', 0, 'Not Available', 'Not Available'), (4, 'S0374', 'AARUBOTEY GOVERNMENT PRIMARY SCHOOL', 'Not Available', 0, 'Available', 2, 'Not Available', 'Not Available', 0, 'Not Available', 'Not Available'), (5, 'S0218', 'ADAMPOOL GOVERNMENT JUNIOR HIGH SCHOOL', 'Available', 217, 'Available', 5, 'Available', 'Available', 1, 'Available', 'Not Available'), (6, 'S1064', 'ADONAI HOMES , NAYA BAZAR', 'Available', 0, 'Available', 0, 'Not Available', 'Available', 2, 'Not Available', 'Available'), (7, 'C1348', 'ADVANCED TECHNICAL TRAINING CENTRE', 'Available', 0, 'Available', 0, 'Available', 'Available', 0, 'Available', 'Available')  ... displaying 10 of 1256 total bound parameter sets ...  (1254, 'S0185', 'ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL', 'Available', 0, 'Available', 5, 'Not Available', 'Available', 1, 'Not Available', 'Not Available'), (1255, 'S0267', 'ZOOM GOVERNMENT SECONDARY SCHOOL', 'Not Available', 0, 'Available', 6, 'Available', 'Available', 1, 'Available', 'Not Available'))
# 2022-02-09 15:50:43,288 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Write your SQL query in this string
#sql = """
#Replace this text
#with your query!

## Read the sql query into pandas to view the results
#df = pd.read_sql_query(sql, engine)
#df.head()

# %%
school.rename(columns = {'DistrictHQDistance (in Km)':'DistrictHQDistance', 'CRCDistance (in Km)':'CRCDistance',
                              'BACDistance (in Km)':'BACDistance'}, inplace = True)
school.head()
# Out:
#   DistrictName EstablishmentCode  ... HighestClass BoardName
# 0         East             S0169  ...      Class 5       NaN
# 1         East             S0099  ...     Class 12  C.B.S.E.
# 2         East             S0848  ...     Class 10  C.B.S.E.
# 3         East             S0190  ...      Class 8       NaN
# 4         East             S0111  ...     Class 10  C.B.S.E.
#
# [5 rows x 30 columns]

# %%
facility = pd.read_csv('/content/School_Facility_Details.csv')
facility.head(2)
# Out:
#   EstablishmentCode  ... IsSportsStoreRoomAvailable
# 0             S1034  ...              Not Available
# 1             S0516  ...              Not Available
#
# [2 rows x 11 columns]

# %%
# create sqlite engine
engine = create_engine('sqlite:///school.db', echo=True)
# create connection to engine
conn = engine.connect()

# %%
# add the dataframe as a table in sqlite
sqlite_table = "school_det"
school.to_sql(sqlite_table, conn, if_exists='fail')

# add the dataframe as a table in sqlite
sqlite_table = "facility_det"
facility.to_sql(sqlite_table, conn, if_exists='fail')
# Out:
# 2022-02-09 16:19:58,196 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_det")
# 2022-02-09 16:19:58,205 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 16:19:58,214 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_det")
# 2022-02-09 16:19:58,218 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 16:19:58,244 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_det (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance" FLOAT,
# 	"CRCDistance" FLOAT,
# 	"BACDistance" FLOAT,
# 	"IsRecognized" TEXT,
# 	"RecognizedBy" TEXT,
# 	"ContactPersonName" FLOAT,
# 	"LowestClass" TEXT,
# 	"HighestClass" TEXT,
# 	"BoardName" TEXT
# )
#
#
# 2022-02-09 16:19:58,252 INFO sqlalchemy.engine.Engine [no key 0.00818s] ()
# 2022-02-09 16:19:58,272 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 16:19:58,278 INFO sqlalchemy.engine.Engine CREATE INDEX ix_school_det_index ON school_det ("index")
# 2022-02-09 16:19:58,283 INFO sqlalchemy.engine.Engine [no key 0.00463s] ()
# 2022-02-09 16:19:58,304 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 16:19:58,351 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-02-09 16:19:58,741 INFO sqlalchemy.engine.Engine INSERT INTO school_det ("index", "DistrictName", "EstablishmentCode", "EstablishmentName", "BRCName", "CRCName", "SchoolLevel", "ManagementName", "LocalityHabitation", "SubdivisionName", "ConstituencyName", "RevenueBlockName", "CivicBodyName", "WardName", "PostOfficeName", "PhoneNo", "FaxNo", "EmailID", "Website", "LocatedInRuralOrUrban", "DiseCode", "EstablishedDate", "DistrictHQDistance", "CRCDistance", "BACDistance", "IsRecognized", "RecognizedBy", "ContactPersonName", "LowestClass", "HighestClass", "BoardName") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-02-09 16:19:58,755 INFO sqlalchemy.engine.Engine [generated in 0.35056s] ((0, 'East', 'S0169', 'BUDANG GOVERNMENT PRIMARY SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'BUDANG', 'Gangtok', 'Rhenock', 'Central Pendam', 'Central Pendam', 'Sajong', 'Upper Pendam', None, None, None, None, 'Urban Area', None, '28126', 58.0, 8.0, 16.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 5', None), (1, 'East', 'S0099', 'CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SSS', 'State Govt.', 'CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Karmithang', 'Upper Pendam', '3592263812', None, None, None, 'Urban Area', '800401', '15342', 50.0, 0.0, 6.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 12', 'C.B.S.E.'), (2, 'East', 'S0848', 'CENTRAL POINT ACADEMY, CENTRAL PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'Private (Unaided)', 'UPPER BHURUNG CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Burung', 'Upper Pendam', '03592263809/263960', None, 'ksu_5162@yahoo.com', 'www.facebook.com/khanalkeshav (Group-CPA)', 'Urban Area', None, '37257.38680555556', 49.0, 1.5, 6.0, 'Recognized', 'HRDD, GOVT. OF SIKKIM', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (3, 'East', 'S0190', 'CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'JHS', 'State Govt.', 'CHEURIBOTEY', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Cheuribotey', 'Duga', None, None, None, None, 'Urban Area', None, '28856', 60.0, 6.0, 6.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 8', None), (4, 'East', 'S0111', 'DUGA GOVERNMENT SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'State Govt.', 'DUGA', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Duga', 'Duga', '9832082915', None, 'dugaschool@gmail.com', None, 'Urban Area', None, '1828', 52.0, 0.0, 0.5, 'Recognized', 'c.b.s.e.', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (5, 'East', 'S0856', 'EASWARAMMA SAI GURUKOOL ACCADEMY', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'RALUNG', 'Gangtok', 'West Pandam', 'Central Pendam', 'West Pendam', 'Ralang', 'West Pendam', '9733056624', None, None, None, 'Urban Area', None, '40179.66805555556', 0.0, 0.2, 0.2, 'Recognized', None, None, 'Class 1', 'Class 5', None), (6, 'East', 'S0870', 'ETERNAL ENGLISH SCHOOL, WEST PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'SAKHU WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Sakhu', 'Sakhu Busty', '9734190544', None, None, None, 'Urban Area', None, '37300.66805555556', 42.0, 3.0, 4.0, 'Recognized', 'HRDD OF SIKKIM', None, 'Class 1', 'Class 5', None), (7, 'East', 'S0157', 'KHANI GOAN GOVERNMENT PRIMARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Khanigaon', 'West Pendam', '9832470263', None, None, None, 'Urban Area', '801801', '29587', 45.0, 5.0, 4.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 5', 'C.B.S.E.')  ... displaying 10 of 1249 total bound parameter sets ...  (1247, 'West', 'S0340', 'TINGTING GAON GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TING TING GAON', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Tingting', 'Yuksom', '9593377402', None, None, None, 'Urban Area', '100282', '29587', 36.0, 3.0, 6.0, 'Recognized', 'STATE GOVERNMENT', None, 'Class 1', 'Class 5', None), (1248, 'West', 'S0542', 'TSONG GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TSONG', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Yoksam', 'Yuksom', No ...
# 2022-02-09 16:19:58,824 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 16:19:58,853 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("facility_det")
# 2022-02-09 16:19:58,855 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 16:19:58,857 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("facility_det")
# 2022-02-09 16:19:58,859 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-09 16:19:58,866 INFO sqlalchemy.engine.Engine
# CREATE TABLE facility_det (
# 	"index" BIGINT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"IsLibraryAvailable" TEXT,
# 	"AvailableBooksCount" BIGINT,
# 	"IsFireExtgAvailable" TEXT,
# 	"ExtinguisherCount" BIGINT,
# 	"HOIRoomAvailable" TEXT,
# 	"IsStaffRoomAvailable" TEXT,
# 	"NoofStaffRoom" BIGINT,
# 	"IsLockerForStaffAvailable" TEXT,
# 	"IsSportsStoreRoomAvailable" TEXT
# )
#
#
# 2022-02-09 16:19:58,869 INFO sqlalchemy.engine.Engine [no key 0.00291s] ()
# 2022-02-09 16:19:58,890 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 16:19:58,892 INFO sqlalchemy.engine.Engine CREATE INDEX ix_facility_det_index ON facility_det ("index")
# 2022-02-09 16:19:58,895 INFO sqlalchemy.engine.Engine [no key 0.00320s] ()
# 2022-02-09 16:19:58,910 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-09 16:19:58,917 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-02-09 16:19:58,953 INFO sqlalchemy.engine.Engine INSERT INTO facility_det ("index", "EstablishmentCode", "EstablishmentName", "IsLibraryAvailable", "AvailableBooksCount", "IsFireExtgAvailable", "ExtinguisherCount", "HOIRoomAvailable", "IsStaffRoomAvailable", "NoofStaffRoom", "IsLockerForStaffAvailable", "IsSportsStoreRoomAvailable") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-02-09 16:19:58,955 INFO sqlalchemy.engine.Engine [generated in 0.03081s] ((0, 'S1034', '(I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PRIMARY SCHOOL, RIMBI', 'Not Available', 0, 'Available', 1, 'Available', 'Not Available', 0, 'Not Available', 'Not Available'), (1, 'S0516', '10TH MILE GOVERNMENT PRIMARY SCHOOL', 'Not Available', 0, 'Not Available', 0, 'Available', 'Available', 1, 'Not Available', 'Not Available'), (2, 'S0237', '4TH MILE GOVERNMENT JUNIOR HIGH SCHOOL', 'Not Available', 0, 'Available', 2, 'Not Available', 'Not Available', 0, 'Not Available', 'Not Available'), (3, 'S0692', 'AAPGAZI GOVERNMENT PRIMARY SCHOOL', 'Not Available', 0, 'Not Available', 0, 'Not Available', 'Not Available', 0, 'Not Available', 'Not Available'), (4, 'S0374', 'AARUBOTEY GOVERNMENT PRIMARY SCHOOL', 'Not Available', 0, 'Available', 2, 'Not Available', 'Not Available', 0, 'Not Available', 'Not Available'), (5, 'S0218', 'ADAMPOOL GOVERNMENT JUNIOR HIGH SCHOOL', 'Available', 217, 'Available', 5, 'Available', 'Available', 1, 'Available', 'Not Available'), (6, 'S1064', 'ADONAI HOMES , NAYA BAZAR', 'Available', 0, 'Available', 0, 'Not Available', 'Available', 2, 'Not Available', 'Available'), (7, 'C1348', 'ADVANCED TECHNICAL TRAINING CENTRE', 'Available', 0, 'Available', 0, 'Available', 'Available', 0, 'Available', 'Available')  ... displaying 10 of 1256 total bound parameter sets ...  (1254, 'S0185', 'ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL', 'Available', 0, 'Available', 5, 'Not Available', 'Available', 1, 'Not Available', 'Not Available'), (1255, 'S0267', 'ZOOM GOVERNMENT SECONDARY SCHOOL', 'Not Available', 0, 'Available', 6, 'Available', 'Available', 1, 'Available', 'Not Available'))
# 2022-02-09 16:19:58,966 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Write your SQL query in this string
sql = """
SELECT AVG(BACDistance) AS avg_bac_distance
FROM school_det
"""
# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-02-09 16:23:25,125 INFO sqlalchemy.engine.Engine
# SELECT AVG(BACDistance) AS avg_bac_distance
# FROM school_det
#
# 2022-02-09 16:23:25,133 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distance
# 0         12.681822

# %%
# Write your SQL query in this string
sql = """
SELECT AVG(BACDistance) AS avg_bac_distance
FROM school_det
GROUP BY SchoolLevel;
"""
# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
# Out:
# 2022-02-09 16:23:13,072 INFO sqlalchemy.engine.Engine
# SELECT AVG(BACDistance) AS avg_bac_distance
# FROM school_det
# GROUP BY SchoolLevel;
#
# 2022-02-09 16:23:13,079 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
# Write your SQL query in this string
sql = """
SELECT AVG(BACDistance) AS avg_bac_distance
FROM school_det
GROUP BY SchoolLevel
HAVING avg_bac_distance >= 10
"""
# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-02-09 16:23:41,715 INFO sqlalchemy.engine.Engine
# SELECT AVG(BACDistance) AS avg_bac_distance
# FROM school_det
# GROUP BY SchoolLevel
# HAVING avg_bac_distance >= 10
#
# 2022-02-09 16:23:41,717 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distance
# 0         13.692647
# 1         12.830787
# 2         12.630872
# 3         10.863095

# %%
# Write your SQL query in this string
sql = """
SELECT *
FROM school_det s INNER JOIN facility_det f
ON s.EstablishmentCode = f.EstablishmentCode
LIMIT 50
"""
# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df
# Out:
# 2022-02-09 16:24:03,042 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_det s INNER JOIN facility_det f
# ON s.EstablishmentCode = f.EstablishmentCode
# LIMIT 50
#
# 2022-02-09 16:24:03,044 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName  ... IsLockerForStaffAvailable IsSportsStoreRoomAvailable
# 0       0         East  ...             Not Available              Not Available
# 1       1         East  ...             Not Available                  Available
# 2       2         East  ...                 Available                  Available
# 3       3         East  ...             Not Available              Not Available
# 4       4         East  ...             Not Available              Not Available
# 5       5         East  ...             Not Available              Not Available
# 6       6         East  ...             Not Available              Not Available
# 7       7         East  ...                 Available              Not Available
# 8       8         East  ...             Not Available                  Available
# 9       9         East  ...             Not Available              Not Available
# 10     10         East  ...             Not Available              Not Available
# 11     11         East  ...             Not Available              Not Available
# 12     12         East  ...             Not Available              Not Available
# 13     13         East  ...             Not Available              Not Available
# 14     14         East  ...             Not Available              Not Available
# 15     15         East  ...             Not Available              Not Available
# 16     16         East  ...             Not Available              Not Available
# 17     17         East  ...             Not Available              Not Available
# 18     18         East  ...             Not Available                  Available
# 19     19         East  ...                 Available              Not Available
# 20     20         East  ...             Not Available              Not Available
# 21     21         East  ...             Not Available              Not Available
# 22     22         East  ...                 Available                  Available
# 23     23         East  ...             Not Available                  Available
# 24     24         East  ...                 Available              Not Available
# 25     25         East  ...             Not Available              Not Available
# 26     26         East  ...                 Available                  Available
# 27     27         East  ...                 Available              Not Available
# 28     28         East  ...             Not Available                  Available
# 29     29         East  ...             Not Available              Not Available
# 30     30         East  ...             Not Available              Not Available
# 31     31         East  ...                 Available              Not Available
# 32     32         East  ...             Not Available                  Available
# 33     33         East  ...             Not Available              Not Available
# 34     34         East  ...             Not Available                  Available
# 35     35         East  ...             Not Available              Not Available
# 36     36         East  ...             Not Available              Not Available
# 37     37         East  ...             Not Available              Not Available
# 38     38         East  ...             Not Available              Not Available
# 39     39         East  ...             Not Available              Not Available
# 40     40         East  ...                 Available                  Available
# 41     41         East  ...             Not Available              Not Available
# 42     42         East  ...             Not Available                  Available
# 43     43         East  ...             Not Available              Not Available
# 44     44         East  ...             Not Available              Not Available
# 45     45         East  ...             Not Available              Not Available
# 46     46         East  ...             Not Available              Not Available
# 47     47         East  ...             Not Available              Not Available
# 48     48         East  ...             Not Available              Not Available
# 49     49         East  ...             Not Available              Not Available
#
# [50 rows x 43 columns]

# %%
# Write your SQL query in this string
sql = """
SELECT *
FROM school_det s INNER JOIN facility_det f
ON s.EstablishmentCode = f.EstablishmentCode
WHERE s.SchoolLevel = 'PS' AND f.IsLibraryAvailable = 'Not Available'
"""
# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-02-09 16:24:18,056 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_det s INNER JOIN facility_det f
# ON s.EstablishmentCode = f.EstablishmentCode
# WHERE s.SchoolLevel = 'PS' AND f.IsLibraryAvailable = 'Not Available'
#
# 2022-02-09 16:24:18,060 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName  ... IsLockerForStaffAvailable IsSportsStoreRoomAvailable
# 0      5         East  ...             Not Available              Not Available
# 1      8         East  ...             Not Available                  Available
# 2     15         East  ...             Not Available              Not Available
# 3     16         East  ...             Not Available              Not Available
# 4     20         East  ...             Not Available              Not Available
#
# [5 rows x 43 columns]

# %%
sql = """
SELECT *
FROM school_det s INNER JOIN facility_det f
ON s.EstablishmentCode = f.EstablishmentCode
WHERE s.SchoolLevel = 'PS' AND f.IsLibraryAvailable = 'Not Available'
ORDER BY s.EstablishmentName;
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-02-09 16:59:50,148 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_det s INNER JOIN facility_det f
# ON s.EstablishmentCode = f.EstablishmentCode
# WHERE s.SchoolLevel = 'PS' AND f.IsLibraryAvailable = 'Not Available'
# ORDER BY s.EstablishmentName;
#
# 2022-02-09 16:59:50,157 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName  ... IsLockerForStaffAvailable IsSportsStoreRoomAvailable
# 0   1219         West  ...             Not Available              Not Available
# 1     54         East  ...             Not Available              Not Available
# 2    816        South  ...             Not Available              Not Available
# 3   1102         West  ...             Not Available              Not Available
# 4    209         East  ...             Not Available              Not Available
#
# [5 rows x 43 columns]
